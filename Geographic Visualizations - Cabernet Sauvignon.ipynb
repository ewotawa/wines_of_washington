# %% [markdown]
# # Data Visualizations:
# ## Alphabetical Guide to the Wines of Washington (Wine Spectator, Sep 2020)
# ### Geographic Visualizations on Summary Statistics
# ### Cabernet Sauvignon

# %% [markdown]
# ### File Setup

# %%
# import and initialize main python libraries
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns

# import os, shutil for file navigation
import os
import shutil
import glob

# import other packages
import geopandas as gpd

# %%
# initialize visualization set
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(10,6))

# Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# ### Data Frame Import

# %%
df_wines = pd.read_csv('./Alphabetical Guide to Washington.csv')
df_wines.shape
# Out:
# (418, 9)

# %%
df_wines.sample(10)
# Out:
#       ID                 Winery  \
# 93    94         CHESTER-KIDDER
# 382  383                  TENOR
# 75    76              CASASMITH
# 367  368          SPRING VALLEY
# 116  117                 DUNHAM
# 94    95            CITY LIMITS
# 20    21                  BEAST
# 25    26                   BETZ
# 109  110  DOMAINE STE. MICHELLE
# 223  224           LIBERTY LAKE
#
#                                                   Wine  Score  Price  \
# 93                                Columbia Valley 2016     89   60.0
# 382                        Merlot Columbia Valley 2016     89   64.0
# 75   Sangiovese Wahluke Slope Cinghiale Wahluke Slo...     84   25.0
# 367             Syrah Walla Walla Valley Nina Lee 2016     92   50.0
# 116       Cabernet Sauvignon Columbia Valley XXII 2016     90   45.0
# 94             Cabernet Sauvignon Columbia Valley 2016     83   15.0
# 20                     Wildebeest Columbia Valley 2016     87   24.0
# 25                   Clos de Betz Columbia Valley 2016     93   60.0
# 109                       Extra Dry Columbia Valley NV     84   13.0
# 223                    Syrah Red Mountain Reserve 2016     92   40.0
#
#             Grape_Blend                 AVA                    Vineyard  \
# 93            Red Blend     Columbia Valley                         NaN
# 382              Merlot     Columbia Valley                         NaN
# 75           Sangiovese       Wahluke Slope  Slope & Rosebud Vineyards
# 367               Syrah  Walla Walla Valley                         NaN
# 116  Cabernet Sauvignon     Columbia Valley                         NaN
# 94   Cabernet Sauvignon     Columbia Valley                         NaN
# 20            Red Blend     Columbia Valley                         NaN
# 25   Red Bordeaux Blend     Columbia Valley                         NaN
# 109           Extra Dry     Columbia Valley                         NaN
# 223               Syrah        Red Mountain                         NaN
#
#        Year
# 93   2016.0
# 382  2016.0
# 75   2017.0
# 367  2016.0
# 116  2016.0
# 94   2016.0
# 20   2016.0
# 25   2016.0
# 109     NaN
# 223  2016.0

# %% [markdown]
# ### Summary Statistics by AVA across all Grapes and Blends

# %%
# What is the average score by AVA in the Alphabetical Guide to Washington?

df_score_by_ava = df_wines[['AVA', 'Score']].groupby('AVA').mean()

df_score_by_ava
# Out:
#                                       Score
# AVA
# Ancient Lakes of Columbia Valley  90.000000
# Columbia Valley                   88.490099
# Horse Heaven Hills                88.159091
# Lake Chelan                       89.000000
# Red Mountain                      90.478261
# Royal Slope                       90.285714
# Snipes Mountain                   90.000000
# Wahluke Slope                     89.000000
# Walla Walla Valley                90.416667
# Yakima Valley                     89.000000

# %%
# What is the average price by AVA in the Alphabetical Guide to Washington?

df_price_by_ava = df_wines[['AVA', 'Price']].groupby('AVA').mean()

df_price_by_ava
# Out:
#                                       Price
# AVA
# Ancient Lakes of Columbia Valley  22.000000
# Columbia Valley                   31.040000
# Horse Heaven Hills                26.545455
# Lake Chelan                       35.000000
# Red Mountain                      57.543478
# Royal Slope                       95.000000
# Snipes Mountain                   70.000000
# Wahluke Slope                     29.500000
# Walla Walla Valley                49.166667
# Yakima Valley                     32.320000

# %% [markdown]
# ### Summary Statistics by AVA for six best represented Grapes and Blends

# %%
# What is the average score by grape or blend by AVA in the Alphabetical Guide to Washington?

df_cabsauv     = df_wines[(df_wines.Grape_Blend == 'Cabernet Sauvignon')]
df_syrah       = df_wines[(df_wines.Grape_Blend == 'Syrah')]
df_redblend    = df_wines[(df_wines.Grape_Blend == 'Red Blend')]
df_redbordeaux = df_wines[(df_wines.Grape_Blend == 'Red Bordeaux Blend')]
df_chardonnay  = df_wines[(df_wines.Grape_Blend == 'Chardonnay')]
df_merlot      = df_wines[(df_wines.Grape_Blend == 'Merlot')]

df_syrah.sample(5)
# Out:
#       ID          Winery                                               Wine  \
# 190  191               K  Syrah Washington Old Bones Stoneridge Vineyard...
# 309  310        REYNVAAN         Syrah Walla Walla Valley In The Hills 2017
# 186  187               K   Syrah Walla Walla Valley Phil Lane Vineyard 2016
# 214  215  L'ECOLE NO. 41                         Syrah Columbia Valley 2017
# 367  368   SPRING VALLEY             Syrah Walla Walla Valley Nina Lee 2016
#
#      Score  Price Grape_Blend                 AVA              Vineyard  \
# 190     91  140.0       Syrah         Royal Slope  Stoneridge Vineyard
# 309     93   80.0       Syrah  Walla Walla Valley                   NaN
# 186     91   70.0       Syrah  Walla Walla Valley    Phil Lane Vineyard
# 214     87   25.0       Syrah     Columbia Valley                   NaN
# 367     92   50.0       Syrah  Walla Walla Valley                   NaN
#
#        Year
# 190  2016.0
# 309  2017.0
# 186  2016.0
# 214  2017.0
# 367  2016.0

# %%
# Data for map visualization: Cabernet Sauvignon

df_cabsauv_count = df_cabsauv.groupby('AVA')['Grape_Blend'].count()
df_cabsauv_score = df_cabsauv.groupby('AVA')['Score'].mean()
df_cabsauv_price = df_cabsauv.groupby('AVA')['Price'].mean()

# Data for map visualization: Syrah

df_syrah_count = df_syrah.groupby('AVA')['Grape_Blend'].count()
df_syrah_score = df_syrah.groupby('AVA')['Score'].mean()
df_syrah_price = df_syrah.groupby('AVA')['Price'].mean()

# Data for map visualization: Red Blend

df_redblend_count = df_redblend.groupby('AVA')['Grape_Blend'].count()
df_redblend_score = df_redblend.groupby('AVA')['Score'].mean()
df_redblend_price = df_redblend.groupby('AVA')['Price'].mean()

# Data for map visualization: Red Bordeaux Blend

df_redbordeaux_count = df_redbordeaux.groupby('AVA')['Grape_Blend'].count()
df_redbordeaux_score = df_redbordeaux.groupby('AVA')['Score'].mean()
df_redbordeaux_price = df_redbordeaux.groupby('AVA')['Price'].mean()

# Data for map visualization: Chardonnay

df_chardonnay_count = df_chardonnay.groupby('AVA')['Grape_Blend'].count()
df_chardonnay_score = df_chardonnay.groupby('AVA')['Score'].mean()
df_chardonnay_price = df_chardonnay.groupby('AVA')['Price'].mean()

# Data for map visualization: Merlot

df_merlot_count = df_merlot.groupby('AVA')['Grape_Blend'].count()
df_merlot_score = df_merlot.groupby('AVA')['Score'].mean()
df_merlot_price = df_merlot.groupby('AVA')['Price'].mean()

# %% [markdown]
# ## Geographic Processing
#
# See *Geographic Visualization* notebook for details on shapefile processing. This notebook uses the concatenated shapefile result of that process.
#
# ### Open Vector Maps

# %%
shp_path = './ava_all/ava_shapefiles.shp'
sf = shp.Reader(shp_path)

# %%
# Number of records (shapes) in concatenated shape file. Here, numbers of AVA polygons.
len(sf.shapes())
# Out:
# 16

# %%
# Explore one shapefile record.
sf.records()[1]
# Out:
# Record #1: [255, 'Royal Slope', 0, 0.0, 'Washington', '', '2', 'None', 'Columbia Valley', 1599004800000, 'Established', '27 CFR 9.271', 'None', '', 'Adams, Grant', 0.074763210199762, 1.97896346427747, 'F']

# %% [markdown]
# ### Convert shapefiles into a Pandas dataframe

# %%
# Convert the shapefile into a Pandas dataframe
def read_shapefile(sf):
    # read a shapefile into a Pandas dataframe with a 'coords' column holding the geometry information.
    # this uses the pyshp package.
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    
    return df

# %%
# Present shapefile as dataframe.

df = read_shapefile(sf)
df
# Out:
#     OBJECTID                              Name  Id          Area  \
# 0        216                    Columbia Gorge   0    621.896085
# 1        255                       Royal Slope   0      0.000000
# 2         67                Walla Walla Valley   0   1035.582049
# 3        226  Ancient Lakes of Columbia Valley   0    570.568421
# 4        227                       Lake Chelan   0    111.898347
# 5        162                Lewis-Clark Valley   0   1008.773304
# 6        144                      Red Mountain   0     14.916350
# 7        220                Horse Heaven Hills   0   1860.765196
# 8         66                   Columbia Valley   0  38088.772849
# 9        219                 Rattlesnake Hills   0    245.157935
# 10       251                    Candy Mountain   0      0.000000
# 11       218                   Snipes Mountain   0     13.333227
# 12       217                     Wahluke Slope   0    268.402450
# 13       156                       Puget Sound   0  15522.885901
# 14       252                     Yakima Valley   0   2316.412983
# 15       228                    Naches Heights   0     45.242237
#
#                 States        Phase Level_  \
# 0   Oregon, Washington    Phase XIV      1
# 1           Washington                   2
# 2   Oregon, Washington     Phase VI      2
# 3           Washington    Phase XIX      2
# 4           Washington  Phase XVIII      2
# 5    Idaho, Washington    Phase XXI      1
# 6           Washington   Phase XIII      3
# 7           Washington     Phase XV      2
# 8   Oregon, Washington      Phase V      1
# 9           Washington    Phase XVI      3
# 10          Washington
# 11          Washington   Phase XVII      3
# 12          Washington    Phase XVI      2
# 13          Washington    Phase XII      1
# 14          Washington      Phase V      2
# 15          Washington  Phase XVIII      2
#
#                                             Contains_  \
# 0                                                None
# 1                                                None
# 2              The Rocks District of Milton-Freewater
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8   Ancient Lakes of Columbia Valley, Candy Mounta...
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14  Candy Mountain, Rattlesnake Hills, Red Mountai...
# 15                                               None
#
#                             Within     Establishe       Status    CFR_Sectio  \
# 0                             None  1084147200000  Established  27 CFR 9.178
# 1                  Columbia Valley  1599004800000  Established  27 CFR 9.271
# 2                  Columbia Valley   444873600000  Established   27 CFR 9.91
# 3                  Columbia Valley  1350518400000  Established  27 CFR 9.227
# 4                  Columbia Valley  1232496000000  Established  27 CFR 9.215
# 5                             None  1461110400000  Established  27 CFR 9.256
# 6   Columbia Valley, Yakima Valley   986860800000  Established  27 CFR 9.167
# 7                  Columbia Valley  1120176000000  Established  27 CFR 9.188
# 8                             None   469152000000  Established   27 CFR 9.74
# 9   Columbia Valley, Yakima Valley  1140220800000  Established  27 CFR 9.193
# 10  Columbia Valley, Yakima Valley  1600992000000  Established  27 CFR 9.272
# 11  Columbia Valley, Yakima Valley  1232496000000  Established  27 CFR 9.213
# 12                 Columbia Valley  1133913600000  Established  27 CFR 9.192
# 13                            None   812764800000  Established  27 CFR 9.151
# 14                 Columbia Valley   418262400000  Established   27 CFR 9.69
# 15                 Columbia Valley  1323820800000  Established  27 CFR 9.222
#
#    Partially_ Note                                           Counties  \
# 0        None        OR:  Hood River, Wasco; WA:  Klickitat, Skamania
# 1        None                                            Adams, Grant
# 2        None                         OR:  Umatilla; WA:  Walla Walla
# 3        None                                Douglas, Grant, Kittitas
# 4        None                                                  Chelan
# 5        None       ID: Clearwater, Latah; WA: Asotin, Garfield, W...
# 6        None                                                  Benton
# 7        None                               Benton, Klickitat, Yakima
# 8        None       OR:  Gilliman, Morrow, Sherman, Umatilla, Wasc...
# 9        None                                                  Yakima
# 10       None                                                  Benton
# 11       None                                                  Yakima
# 12       None                                                   Grant
# 13       None       Callam, Island, Jefferson, King, Kitsap, Mason...
# 14       None                                                  Benton
# 15       None                                                  Yakima
#
#     Shape_Area  Shape_Leng selected  \
# 0     0.090822    1.933248        F
# 1     0.074763    1.978963        F
# 2     0.150226    4.155462        F
# 3     0.081130    1.382728        F
# 4     0.015688    0.885637        F
# 5     0.145407   16.491167        F
# 6     0.002154    0.244601        F
# 7     0.270045    4.658133        F
# 8     5.477803   38.302919        F
# 9     0.035303    1.207129        F
# 10    0.000354    0.126179        F
# 11    0.001925    0.394656        F
# 12    0.038456    1.331493        F
# 13    2.173432   10.346479        F
# 14    0.334300    5.708497        F
# 15    0.006488    0.552798        F
#
#                                                coords
# 0   [(-121.627176804498, 45.7056269235344), (-121....
# 1   [(-119.980283566903, 46.9857319279403), (-119....
# 2   [(-118.752240225833, 46.0650273989079), (-118....
# 3   [(-120.095377980367, 47.2456320777975), (-120....
# 4   [(-119.9743709105, 47.8474480947289), (-119.97...
# 5   [(-117.229203855546, 46.4239508801636), (-117....
# 6   [(-119.438392430228, 46.2619092390181), (-119....
# 7   [(-119.706752055188, 46.2047744716618), (-119....
# 8   [(-117.229203855546, 46.4239508801636), (-117....
# 9   [(-120.465387337277, 46.520589754441), (-120.4...
# 10  [(-119.348888986321, 46.246167165005), (-119.3...
# 11  [(-120.041325988599, 46.3015047921486), (-120....
# 12  [(-119.932672334025, 46.7815351936077), (-119....
# 13  [(-123.045032989208, 47.5332165344141), (-123....
# 14  [(-119.460090929591, 46.3516132074409), (-119....
# 15  [(-120.587577610544, 46.6318144983111), (-120....

# %% [markdown]
# ### Create Heat Maps
# See *Geographic Visualization* notebook for additional exploration of shapefiles

# %%
# Create a function to separate the source data into bins. Color code those bins.

def calc_color(data, color=None):
    if color   == 1: color_sq = ['#ffccff', '#e0a3e0', '#c27ac2', '#a352a3', '#852985', '#660066']; colors = 'Purples';
    elif color == 2: color_sq = ['#ffcccc', '#ebada3', '#d68f7a', '#c27052', '#ad5229', '#993300']; colors = 'Reds';
    elif color == 3: color_sq = ['#ffff00', '#ebd600', '#d6ad00', '#c28500', '#ad5c00', '#993300']; colors = 'YlOrRd';
    elif color == 4: color_sq = ['#99ccff', '#7aa3e0', '#5c7ac2', '#3d52a3', '#1f2985', '#000066']; colors = 'Blues';
    elif color == 5: color_sq = ['#993333', '#8f293d', '#851f47', '#7a1452', '#700a5c', '#660066']; colors = 'RdPu';
    elif color == 9: color_sq = ['#99ccff', '#7aa3e0', '#5c7ac2', '#3d52a3', '#1f2985', '#000066']; colors = 'Blues';
    else:            color_sq = ['#993333', '#8f293d', '#851f47', '#7a1452', '#700a5c', '#660066']; colors = 'RdPu';
    new_data, bins = pd.qcut(data, 6, retbins=True, labels=list(range(6)))
    color_ton = []
    for val in new_data:
        color_ton.append(color_sq[val])
    if color != 9:
        colors = sns.color_palette(colors, n_colors=6)
        sns.palplot(colors, 0.6);
        for i in range(6):
            print('\n' + str(i+1) + ': ' + str(int(bins[i])) + ' => ' + str(int(bins[i+1]) -1), end = ' ')
        print('\n\n   1   2   3   4   5   6')
    return color_ton, bins;

# %%
# Plot map with specific AVAs, using specific color

def plot_ava_data(sf, title, avas, data=None, color=None, print_id=False):
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    ava_id = []
    for i in avas:
        ava_id.append(df[df.Name == i].index.get_values()[0])
    plot_map_fill_multiples_ids_tone(sf, title, ava_id, print_id, 
                                     color_ton, bins, 
                                     x_lim=None, y_lim=None, figsize=(7, 7));

# %%
# Plot map with lim coordinates

def plot_map_fill_multiples_ids_tone(sf, title, ava, print_id,
                                    color_ton, bins,
                                    x_lim=None, y_lim=None, figsize=(7, 7)):
    
    # plot area and set axes
    plt.figure(figsize = figsize)
    
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)

    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')

        for id in ava:
            shape_ex = sf.shape(id)
            
            # initialize an array of rows and columns with 0 in place of each element
            # array: number of rows = len(shape_ex, point), number of columns = 1
            x_lon = np.zeros((len(shape_ex.points), 1))
            y_lat = np.zeros((len(shape_ex.points), 1))
            for ip in range(len(shape_ex.points)):
                x_lon[ip] = shape_ex.points[ip][0]
                y_lat[ip] = shape_ex.points[ip][1]
            ax.fill(x_lon, y_lat, color_ton[ava.index(id)])
            if print_id != False:
                x0 = np.mean(x_lon)
                y0 = np.mean(y_lat)
                plt.text(x0, y0, id, fontsize=10)

        if (x_lim != None) & (y_lim != None):
            plt.xlim(x_lim)
            plt.ylim(y_lim)

# %% [markdown]
# ### Map visualization: Cabernet Sauvignon

# %%
# df_cabsauv_count, df_cabsauv_score, df_cabsauv_price

title = 'WS Alphabetical Guide to Washington Wines\nAverage Wine Spectator Score by AVA\nCabernet Sauvignon '
data = df_cabsauv_score
names = df_cabsauv_score.index.values

plot_ava_data(sf, title, names, data, 1, True)
# Out:
# 1: 87 => 87
# 2: 88 => 87
# 3: 88 => 88
# 4: 89 => 89
# 5: 90 => 89
# 6: 90 => 91
#
#    1   2   3   4   5   6

# %%
# df_cabsauv_count, df_cabsauv_score, df_cabsauv_price

title = 'WS Alphabetical Guide to Washington Wines\nAverage Price by AVA\nCabernet Sauvignon '
data = df_cabsauv_price
names = df_cabsauv_price.index.values

plot_ava_data(sf, title, names, data, 1, True)
# Out:
# 1: 26 => 28
# 2: 29 => 31
# 3: 32 => 33
# 4: 34 => 42
# 5: 43 => 44
# 6: 45 => 63
#
#    1   2   3   4   5   6
